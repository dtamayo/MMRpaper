# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('paper')

# %%
fig, ax = plt.subplots()
orb1 = plt.Circle((-0.3, 0), 1, fill=False)
orb2 = plt.Circle((0.2, -0.25), 1.6, fill=False)
ax.add_patch(orb1)
ax.add_patch(orb2)
#ax.scatter((0), (0), marker='*', facecolor='yellow', edgecolor='k', s=200)
ax.scatter((0), (0), marker='.', facecolor='yellow', edgecolor='k', s=800)
ax.scatter((-0.3), (0), marker='.', facecolor='k', edgecolor='k', s=200)
ax.scatter((0.2), (-0.25), marker='.', facecolor='k', edgecolor='k', s=200)

ax.annotate("", (-0.03, 0), (-0.3, 0), arrowprops={'shrinkA':0, 'shrinkB':0, 'headlength':6, 'headwidth':4, 'width':0.01, 'linewidth':3, 'color':'k'})
ax.annotate("", (0.02, -0.02), (0.2, -0.25), arrowprops={'shrinkA':0, 'shrinkB':0, 'headlength':6, 'headwidth':4, 'width':0.01, 'linewidth':3, 'color':'k'})
ax.annotate("", (-0.24, -0.035), (0.2, -0.25), arrowprops={'shrinkA':0, 'shrinkB':0, 'headlength':6, 'headwidth':4, 'width':0.01, 'linewidth':3, 'color':'k'})

ax.plot((0.06, 0.71), (0, 0), 'k--', alpha=0.5)
ax.scatter((0.7), (0), marker='.', facecolor='k', edgecolor='k', s=200)
ax.text(0.8, -0.05, r'$Peri_1$', fontsize=18)

ax.plot((-0.03, -0.75), (0.06, 1.05), 'k--', alpha=0.5)
ax.scatter((-0.75), (1.05), marker='.', facecolor='k', edgecolor='k', s=200)
ax.text(-1.1, 1.2, r'$Peri_2$', fontsize=18)

ax.plot((-0.34, -1.23), (0.02, 0.48), 'k--', alpha=0.5)
ax.scatter((-1.23), (0.48), marker='.', facecolor='k', edgecolor='k', s=200)
ax.text(-1.8, 0.45, r'$Peri_{12}$', fontsize=18)

ax.text(0.06, 0.06, r'$S$', fontsize=18)
ax.text(0.2, -0.45, r'$C_2$', fontsize=18)
ax.text(-0.55, -0.15, r'$C_1$', fontsize=18)

ax.text(-0.38, 0.07, r'$a\bf{e}_1$', weight='bold', fontsize=16)
ax.text(0.16, -0.17, r'$a\bf{e}_2$', weight='bold', fontsize=16)
ax.text(-0.3, -0.3, r'$a\bf{e}_{12}$', weight='bold', fontsize=16)

ax.set_xlim([-1.5, 1.85])
ax.set_ylim([-1.9, 1.5])
ax.set_aspect('equal')
ax.axis('off')
fig.savefig('equiv.pdf', bbox_inches='tight')
